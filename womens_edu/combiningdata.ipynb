# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/cs230/womens_edu
# Out:
# /content/drive/.shortcut-targets-by-id/1UmSDcE4n7YnHUjCIvlrq4izeyNfRvNRj/cs230/womens_edu

# %%
dataset_root_dir = '/content/drive/MyDrive/Colab Notebooks/cs230/womens_edu/data'

# %%
ls
# Out:
#  best_model.pth
#  combiningdata.ipynb
#  data/
#  data_preprocessing.ipynb
#  filter_combined_data.ipynb
#  FinalHayamulti_modal_regressor.ipynb
#  final_multi_modal_regressor_1street.ipynb
# 'Final Table.gsheet'
#  haya_data_pre_processing.ipynb
#  Model.ipynb
#  multi_modal_regressor_1street.ipynb
#  multi_modal_regressor.ipynb
#  pretrained_resnet/
# 'Project Milestone Tables and Figures.gdoc'
#  runs/
#  saved_models/
#  womens_edu_regressor.ipynb

# %%
# !git config --global user.email "hayah@stanford.edu"
# !git config --global user.name "hayah08"

# %%
username='hayah08'
repository='cs230'
git_token='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'

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/disaalda/cs230.git (fetch)
# origin	https://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@github.com/disaalda/cs230.git (push)

# %%
# !git remote rm origin

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git add combiningdata.ipynb

# %%
# !git commit -m 'initial commit'
# Out:
# [main dec0013] initial commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite womens_edu/combiningdata.ipynb (97%)

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
IA = pd.read_csv('IA_satellite.csv')
AL_DR = pd.read_csv('AL_DR_satellite.csv')
EG_HT = pd.read_csv('EG_HT_satellite.csv')
TD_ZW = pd.read_csv('TD_ZW_satellite.csv')
ID_MZ = pd.read_csv('ID_MZ_satellite.csv')
NG_SZ = pd.read_csv('NG_SZ_satellite.csv')

# %%
combined = pd.concat([AL_DR, IA, EG_HT, TD_ZW, ID_MZ,NG_SZ], axis=0)

# %%
pd.unique(combined['year'])
# Out:
# array([2008, 2017, 2010, 2016, 2006, 2011, 2015, 2000, 2004, 2007, 2014,
#        1999, 2003, 1996, 2001, 2012, 2013, 1998, 2018, 2005, 2019, 2009,
#        2002, 1997])

# %%
pd.unique(combined['cc'])
# Out:
# array(['AL', 'AM', 'AO', 'BD', 'BF', 'BJ', 'BO', 'BU', 'CD', 'CI', 'CM',
#        'CO', 'DR', 'IA', 'EG', 'ET', 'GH', 'GN', 'GU', 'GY', 'HN', 'HT',
#        'TG', 'TZ', 'UG', 'ZM', 'ZW', 'ID', 'JO', 'KE', 'KH', 'KY', 'LB',
#        'LS', 'MA', 'MB', 'MD', 'ML', 'MM', 'MW', 'MZ', 'NG', 'NI', 'NM',
#        'NP', 'PE', 'PH', 'PK', 'RW', 'SL', 'SN', 'SZ'], dtype=object)

# %%
df2 = combined.groupby(['cc'])['cc'].count()
print(df2)
# Out:
# cc
# AL     1161
# AM      621
# AO      969
# BD     2931
# BF     1618
# BJ     1579
# BO      997
# BU     1128
# CD      785
# CI      474
# CM     1467
# CO     4633
# DR     1944
# EG     5703
# ET     2560
# GH     1946
# GN     1284
# GU      853
# GY      306
# HN     1122
# HT     1535
# IA    26730
# ID     1312
# JO     3178
# KE     2219
# KH     2236
# KY      314
# LB     1384
# LS     1174
# MA      480
# MB      399
# MD     1750
# ML     2018
# MM      441
# MW     3183
# MZ     1406
# NG     4074
# NI      267
# NM     1287
# NP     1179
# PE     5328
# PH     2747
# PK     1501
# RW     1686
# SL     1677
# SN     2415
# SZ      267
# TG      762
# TZ     3059
# UG     2379
# ZM     1573
# ZW     1409
# Name: cc, dtype: int64

# %%
combined.head()
# Out:
#               DHSID_EA  year  cc        lat        lon  women_edu  \
# 0  AL-2008-5#-00000001  2008  AL  40.822652  19.838321   9.500000
# 1  AL-2008-5#-00000002  2008  AL  40.696846  20.007555   8.600000
# 2  AL-2008-5#-00000003  2008  AL  40.750037  19.974262   9.666667
# 3  AL-2008-5#-00000004  2008  AL  40.798931  19.863338   9.952381
# 4  AL-2008-5#-00000005  2008  AL  40.746123  19.843885   8.937500
#
#                                                 path
# 0  /content/drive/MyDrive/Colab Notebooks/cs230/w...
# 1  /content/drive/MyDrive/Colab Notebooks/cs230/w...
# 2  /content/drive/MyDrive/Colab Notebooks/cs230/w...
# 3  /content/drive/MyDrive/Colab Notebooks/cs230/w...
# 4  /content/drive/MyDrive/Colab Notebooks/cs230/w...

# %%
combined = combined.dropna()
combined['women_edu'].isnull().sum()
# Out:
# 0

# %%
combined.to_csv(os.path.join(dataset_root_dir, 'fullsatellite.csv'))

# %% [markdown]
# STREET IMAGES COMBINED

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/cs230/mapillary/metadata
# Out:
# /content/drive/.shortcut-targets-by-id/1ggRz2Z4ptnOhoXbk9h2qTsEqqk0J9wqr/mapillary/metadata

# %%
ls
# Out:
# AL.csv  BJ.csv  CM.csv  GH.csv  IA.csv  LB.csv  MW.csv  PE.csv  SN.csv  UG.csv
# AM.csv  BO.csv  CO.csv  GN.csv  JO.csv  LS.csv  MZ.csv  PH.csv  TD.csv  ZM.csv
# AO.csv  BU.csv  DR.csv  GU.csv  KE.csv  MD.csv  NG.csv  PK.csv  TG.csv  ZW.csv
# BD.csv  CD.csv  EG.csv  HN.csv  KH.csv  ML.csv  NM.csv  RW.csv  TJ.csv
# BF.csv  CI.csv  ET.csv  HT.csv  KY.csv  MM.csv  NP.csv  SL.csv  TZ.csv

# %%
# use glob to get all the csv files 
# in the folder
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
# This creates a list of dataframes
df_list = (pd.read_csv(file) for file in csv_files)

# Concatenate all DataFrames
big_df   = pd.concat(df_list, ignore_index=True)

# %%
big_df.shape
# Out:
# (1682613, 8)

# %%
big_df.head()
# Out:
#               DHSID_EA country_code  year  img_captured_at    img_lon  \
# 0  AM-2016-7#-00000243           AM  2016    1493995968000  46.374831
# 1  AM-2016-7#-00000243           AM  2016    1493543813000  46.381713
# 2  AM-2016-7#-00000243           AM  2016    1493544013000  46.379005
# 3  AM-2016-7#-00000243           AM  2016    1493544153000  46.379460
# 4  AM-2016-7#-00000243           AM  2016    1493544033000  46.378748
#
#      img_lat            img_id                                      img_path
# 0  39.293200   371204064255607   AM/AM-2016-7#-00000243/371204064255607.jpeg
# 1  39.298763   349474416527216   AM/AM-2016-7#-00000243/349474416527216.jpeg
# 2  39.305671   449548089473346   AM/AM-2016-7#-00000243/449548089473346.jpeg
# 3  39.311068  3928312170585657  AM/AM-2016-7#-00000243/3928312170585657.jpeg
# 4  39.306705   263558198786244   AM/AM-2016-7#-00000243/263558198786244.jpeg

# %%
street = big_df.loc[:, ~big_df.columns.isin(['country_code', 'year'])]

# %% [markdown]
# MERGE TWO

# %%
df  = pd.merge(left=combined, right=street, on=['DHSID_EA'], how='inner', sort = '')

# %%
df.shape
# Out:
# (1649330, 12)

# %%
df.to_csv(os.path.join(dataset_root_dir, 'combinedss.csv'))

# %%
df.head()
# Out:
#               DHSID_EA  year  cc        lat        lon  women_edu  \
# 0  AL-2008-5#-00000105  2008  AL  40.567915  19.632669   8.615385
# 1  AL-2008-5#-00000106  2008  AL  40.572031  19.657091   9.421053
# 2  AL-2008-5#-00000106  2008  AL  40.572031  19.657091   9.421053
# 3  AL-2008-5#-00000115  2008  AL  40.635606  19.652838   8.235294
# 4  AL-2008-5#-00000115  2008  AL  40.635606  19.652838   8.235294
#
#                                                 path  img_captured_at  \
# 0  /content/drive/MyDrive/Colab Notebooks/cs230/w...    1312037822000
# 1  /content/drive/MyDrive/Colab Notebooks/cs230/w...    1312036894000
# 2  /content/drive/MyDrive/Colab Notebooks/cs230/w...    1312034501000
# 3  /content/drive/MyDrive/Colab Notebooks/cs230/w...    1312032453000
# 4  /content/drive/MyDrive/Colab Notebooks/cs230/w...    1312104297000
#
#      img_lon    img_lat            img_id  \
# 0  19.705869  40.535814   138149814963930
# 1  19.718817  40.535614  3956640137736706
# ...

# %%
df
# Out:
#                     DHSID_EA  year  cc        lat        lon  women_edu  \
# 0        AL-2008-5#-00000105  2008  AL  40.567915  19.632669   8.615385
# 1        AL-2008-5#-00000106  2008  AL  40.572031  19.657091   9.421053
# 2        AL-2008-5#-00000106  2008  AL  40.572031  19.657091   9.421053
# 3        AL-2008-5#-00000115  2008  AL  40.635606  19.652838   8.235294
# 4        AL-2008-5#-00000115  2008  AL  40.635606  19.652838   8.235294
# ...                      ...   ...  ..        ...        ...        ...
# 1649325  SN-2018-8#-00000214  2018  SN  12.608355 -15.522625   1.377358
# 1649326  SN-2018-8#-00000214  2018  SN  12.608355 -15.522625   1.377358
# 1649327  SN-2018-8#-00000214  2018  SN  12.608355 -15.522625   1.377358
# 1649328  SN-2018-8#-00000214  2018  SN  12.608355 -15.522625   1.377358
# 1649329  SN-2018-8#-00000214  2018  SN  12.608355 -15.522625   1.377358
#
#                                                       path  img_captured_at  \
# ...

# %%
small = df.loc[:, df.columns.isin(['DHSID_EA', 'cc', 'img_path'])]

# %%
small.head()
# Out:
#               DHSID_EA  cc                                      img_path
# 0  AL-2008-5#-00000105  AL   AL/AL-2008-5#-00000105/138149814963930.jpeg
# 1  AL-2008-5#-00000106  AL  AL/AL-2008-5#-00000106/3956640137736706.jpeg
# 2  AL-2008-5#-00000106  AL  AL/AL-2008-5#-00000106/1001103113629217.jpeg
# 3  AL-2008-5#-00000115  AL   AL/AL-2008-5#-00000115/170221941656904.jpeg
# 4  AL-2008-5#-00000115  AL   AL/AL-2008-5#-00000115/208626260803151.jpeg

# %%
satellite = small['DHSID_EA'].unique()

# %%
streetcount = small.groupby(['cc']).count()

# %%
streetcount.to_csv(os.path.join(dataset_root_dir, 'street_count.csv'))

# %%
satlist = satellite.tolist()

# %%
len(satlist)
# Out:
# 21577

# %%
streetdf = small['img_path'].unique()

# %%
streetlist = streetdf.tolist()

# %%
len(streetlist)
# Out:
# 1649330

# %%
women_edu_sat = combined.loc[combined['DHSID_EA'].isin(satlist)]

# %%
women_edu_sat.to_csv(os.path.join(dataset_root_dir, 'filteredsatellite.csv'))

# %% [markdown]
# SAT COUNTS

# %%
satcounts = women_edu_sat.groupby(['cc']).count()

# %%
satcounts.to_csv(os.path.join(dataset_root_dir, 'sat_counts.csv'))

# %% [markdown]
# STREET IMAGES ONLY

# %%
women_edu_street = big_df.loc[big_df['img_path'].isin(streetlist)]

# %%
women_edu_street.to_csv(os.path.join(dataset_root_dir, 'corrstreet.csv'))

# %%
women_edu_street.head()
# Out:
#               DHSID_EA country_code  year  img_captured_at    img_lon  \
# 0  AM-2016-7#-00000243           AM  2016    1493995968000  46.374831
# 1  AM-2016-7#-00000243           AM  2016    1493543813000  46.381713
# 2  AM-2016-7#-00000243           AM  2016    1493544013000  46.379005
# 3  AM-2016-7#-00000243           AM  2016    1493544153000  46.379460
# 4  AM-2016-7#-00000243           AM  2016    1493544033000  46.378748
#
#      img_lat            img_id                                      img_path
# 0  39.293200   371204064255607   AM/AM-2016-7#-00000243/371204064255607.jpeg
# 1  39.298763   349474416527216   AM/AM-2016-7#-00000243/349474416527216.jpeg
# 2  39.305671   449548089473346   AM/AM-2016-7#-00000243/449548089473346.jpeg
# 3  39.311068  3928312170585657  AM/AM-2016-7#-00000243/3928312170585657.jpeg
# 4  39.306705   263558198786244   AM/AM-2016-7#-00000243/263558198786244.jpeg

# %%
# Out:
#                      cc  img_path
# DHSID_EA
# AL-2008-5#-00000105   1         1
# AL-2008-5#-00000106   2         2
# AL-2008-5#-00000115   2         2
# AL-2008-5#-00000125   1         1
# AL-2008-5#-00000126   1         1
# ...                  ..       ...
# ZW-2015-7#-00000390   4         4
# ZW-2015-7#-00000392  31        31
# ZW-2015-7#-00000394   4         4
# ZW-2015-7#-00000396  95        95
# ZW-2015-7#-00000399   5         5
#
# [21577 rows x 2 columns]
